# %% [markdown]
# # 01. Data Download & Loading
# This notebook handles loading raw data and initial preprocessing.

# %%
import os
import sys
import pandas as pd
import numpy as np

# Add src to path
sys.path.append('../')
from src.data_loader import load_time_series, load_weather_data
from src.preprocessing import preprocess_pipeline

# Load Data
base_dir = '../'
df_ts = load_time_series(base_dir)
df_weather = load_weather_data(base_dir)

print("Time Series Shape:", df_ts.shape)
print("Weather Shape:", df_weather.shape)

# %%
# Preprocess
df_clean = preprocess_pipeline(df_ts, df_weather)
df_clean.head()
