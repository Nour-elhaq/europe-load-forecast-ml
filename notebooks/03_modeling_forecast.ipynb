# %% [markdown]
# # 03. Modeling & Forecasting
# Training Baseline, RF, and XGBoost models.

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('../')
from src.train import main

# Run the trianing pipeline
main()
